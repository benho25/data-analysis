# %%
#To install file the directions at the following link, you should be able to use a simple pip install. Remember to install the dependencies!
url = "http://stanford.edu/~mwaskom/software/seaborn/installing.html"

# %%
import webbrowser
webbrowser.open(url)
# Out:
# True

# %%
# Let's begin by importing what we'll need (You'll probably be copying and pasting this a lot)

# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats librayr from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %% [markdown]
# First of all, source of information for what a histogram actually is: http://en.wikipedia.org/wiki/Histogram

# %%
#Create a random normal-dist dataset
data_set1 = randn(100)

#Plot a histogram of the dataset, note bins=10 by default
plt.hist(data_set1)
# Out:
# (array([ 3.,  5., 18., 24., 14., 20.,  9.,  6.,  0.,  1.]),
#  array([-2.29282043, -1.75806832, -1.2233162 , -0.68856409, -0.15381198,
#          0.38094013,  0.91569225,  1.45044436,  1.98519647,  2.51994859,
#          3.0547007 ]),
#  <a list of 10 Patch objects>)

# %%
# Lets make another dataset
dataset2 = randn(80)
#Plot
plt.hist(dataset2,color='indianred')
# Out:
# (array([ 3.,  2.,  8., 13., 13., 17., 14.,  5.,  3.,  2.]),
#  array([-2.63490726, -2.08252178, -1.5301363 , -0.97775083, -0.42536535,
#          0.12702013,  0.6794056 ,  1.23179108,  1.78417656,  2.33656203,
#          2.88894751]),
#  <a list of 10 Patch objects>)

# %%
# We can use normed to plot on same plot

# Set normed=True replace by density for the plots to be normalized in order to comapre data sets with different number of observations
# Set alpha=0.5 for transperancy

plt.hist(data_set1,density=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)
# Out:
# (array([0.04525825, 0.0905165 , 0.0905165 , 0.        , 0.181033  ,
#         0.181033  , 0.22629125, 0.362066  , 0.2715495 , 0.31680775,
#         0.2715495 , 0.49784075, 0.362066  , 0.2715495 , 0.0905165 ,
#         0.13577475, 0.13577475, 0.        , 0.        , 0.0905165 ]),
#  array([-2.63490726, -2.35871452, -2.08252178, -1.80632904, -1.5301363 ,
#         -1.25394357, -0.97775083, -0.70155809, -0.42536535, -0.14917261,
#          0.12702013,  0.40321286,  0.6794056 ,  0.95559834,  1.23179108,
#          1.50798382,  1.78417656,  2.06036929,  2.33656203,  2.61275477,
#          2.88894751]),
#  <a list of 20 Patch objects>)

# %%
# Make two more random normal dist data sets
data1 = randn(1000)
data2 = randn(1000)

#Can represent joint distributions using joint plots
sns.jointplot(data1,data2)

# %%
# Can also use hex bins for a more concise picture
sns.jointplot(data1,data2,kind='hex')

# %%
# Next we'll learn how to use Kernel Estimation Plots
