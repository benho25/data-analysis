# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats library from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
# Now we'll learn about box and violin plots
url = 'http://en.wikipedia.org/wiki/Box_plot#mediaviewer/File:Boxplot_vs_PDF.svg'

# Let's create two distributions
data1 = randn(100)
data2 = randn(100) + 2 # Off set the mean

# %%
data1
# Out:
# array([-1.08897259, -0.62498506,  0.36391954,  0.08133356, -0.26897554,
#        -0.35209637, -0.70808419,  1.0703037 , -0.28509054, -0.42878568,
#        -0.17166921,  1.95159434, -1.27325475, -1.02684052, -0.1761996 ,
#         0.09042855, -0.22536354,  1.04508917,  0.95797006,  0.59606944,
#        -1.92145084, -1.03498363,  1.451153  , -0.37310089, -1.44410573,
#        -0.56043236, -0.07263013,  2.76809632, -0.77496486, -1.29314588,
#        -1.38552617,  0.4931528 ,  0.69846461, -0.03385071,  0.60711975,
#         0.40123263,  1.39812923,  0.18218155,  0.71418845, -0.80771661,
#         0.62298994, -0.13455785, -0.34755637, -0.22691228,  0.49095191,
#        -0.92371836,  0.48144855,  0.30467571, -0.29207882, -0.14051682,
#         0.76043616,  0.91323891, -1.22992265,  0.52640363, -0.44253867,
#        -2.65022005, -0.37087156, -0.53520576,  0.75303479, -0.09279471,
#         0.02846028,  2.37521839,  0.05931029,  2.81423023, -2.06104329,
#         0.31578833,  1.0435109 , -0.56626114,  0.01603583, -0.03142084,
#         0.50970236, -0.30045051, -1.14867907, -0.63726567, -0.59380547,
#         0.86785872,  0.73932056, -0.71972811,  0.82962512, -0.38718973,
#         0.66806953, -0.54364096,  0.20174318, -0.51081455, -1.14508551,
#         0.49753663,  2.39975884,  0.00494001,  0.59709027, -1.30296484,
#         0.26191474, -0.22835566,  1.31060057,  0.26459629, -0.4056306 ,
#         0.54210208,  1.75245836, -0.44006218, -0.28290754, -0.74767962])

# %%
data2
# Out:
# array([ 2.11501485,  1.2630922 ,  1.43502757,  2.82081972,  1.23738831,
#         1.05641263,  2.53333197,  3.27840206,  2.99477938,  3.0109948 ,
#         2.69950826,  1.71021838,  2.02940492,  2.31597246,  3.27671726,
#         1.33144263,  0.43812291,  3.05094089,  1.54511201,  2.3689798 ,
#         1.91274562,  2.24695964,  1.15553142,  1.96401338, -0.25118646,
#         1.57933181,  2.15337511,  2.90658674,  1.60029918,  1.7737509 ,
#         0.94756899,  1.9936497 ,  2.78772625,  1.70460812,  1.81942677,
#         4.15878338,  1.5054746 ,  2.33138358,  2.30395047,  2.30657094,
#         1.07106582,  1.36667535,  1.14652855,  1.80868527,  2.53589653,
#         1.88309834,  2.12837627,  1.52487643,  2.67122673,  2.30044268,
#         1.65135301,  1.61316126,  0.54074206,  2.16522651,  1.81728739,
#         1.46643824,  2.57997547,  1.81771968,  3.59457448,  3.34549927,
#         2.21617853,  3.27481682,  1.44028836,  1.9134495 ,  0.79407003,
#         2.36364951, -0.04907737,  0.45160256,  2.19260087,  2.08634088,
#         1.57374292,  2.47760771,  1.30581769,  2.76329886,  1.71814505,
#         2.12126629,  0.84768831,  0.88348605,  0.30762007,  2.4008246 ,
#         0.47122345,  1.67556383,  2.31960002,  2.26686083,  2.10648312,
#         1.65443536,  2.37722578,  1.35827537,  3.36327478,  3.54385505,
#         2.70947852,  4.35233117,  1.17092448,  1.83268597,  3.56918183,
#         1.83314524,  2.50537268,  1.95693653,  2.0906656 ,  0.94802739])

# %%
# Now we can create a box plot
sns.boxplot(data=[data1,data2])

# %%
# Notice how the previous plot had outlier points, we can include those with the "whiskers"
sns.boxplot(data=[data1,data2],whis=np.inf)

# %%
# WE can also set horizontal by setting orient to 'h; or 'v'
sns.boxplot(data=[data1,data2],whis=np.inf, orient = 'h')

# %%
# While box plots are great, they can sometimes not give the full picture

# Violin/Viola plots can combine the simplicity of a box plot with the information of a kde plot

# %%
# Let's create an example where a box plot doesn't give the whole picture

# Normal Distribution
data1 = stats.norm(0,5).rvs(100)# rvs to get 100 points

# Two gamma distributions concatenated together (Second one is inverted)
data2 = np.concatenate([stats.gamma(5).rvs(50)-1,
                        -1*stats.gamma(5).rvs(50)])

# Box plot both of them
sns.boxplot(data=[data1,data2],whis=np.inf)

# %%
# From the above plots, you may think that the distributions are fairly similar
# But lets check out what a violin plot reveals
sns.violinplot(data=[data1,data2])

# %%
# Wow, quite revealing!

# %%
# We can also change the bandwidth of the kernel used for the density fit of the violin plots if desired
sns.violinplot(data2,bw=0.01)

# %%
# Much like a rug plot, we can also include the individual points, or sticks
sns.violinplot(data1,inner="stick")

# %%
sns.violinplot(data1)

# %%
#may want to always add kde to understand the distrubution of the plots
